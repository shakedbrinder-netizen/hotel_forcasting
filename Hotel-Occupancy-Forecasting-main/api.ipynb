# %%
import requests
import pprint

URL = 'http://127.0.0.1:8000/predict/weekly'

inputs = {
  "hotel_id": "DT",
  "start_date": "01/09/2026",
  "past_14_days_occupancy": [
    54, 45, 65, 76, 75, 54, 65, 54, 45, 65, 76, 75, 54, 65
  ]
}


response = requests.post(url = URL, json = inputs)
response.json()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/Desktop/Shaked V4/.venv/lib/python3.12/site-packages/urllib3/connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File ~/Desktop/Shaked V4/.venv/lib/python3.12/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...
